# %% [markdown]
# ANANYA JALONHA ASSIGNMENT 4

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
df_AnanyaJalonha=pd.read_csv("/content/winequality-red.csv")

# %% [markdown]
# DATA PREPROCESSING AND STATS

# %%
df_AnanyaJalonha.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df_AnanyaJalonha= df_AnanyaJalonha.sample(frac = 1)

# %%
df_AnanyaJalonha.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 696             7.0              0.65         0.02             2.1      0.066
# 1398            7.0              0.60         0.12             2.2      0.083
# 1100            8.4              0.34         0.42             2.1      0.072
# 196             7.3              0.58         0.30             2.4      0.074
# 894             7.2              0.63         0.03             2.2      0.080
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 696                   8.0                  25.0  0.99720  3.47       0.67
# 1398                 13.0                  28.0  0.99660  3.52       0.62
# 1100                 23.0                  36.0  0.99392  3.11       0.78
# 196                  15.0                  55.0  0.99680  3.46       0.59
# 894                  17.0                  88.0  0.99745  3.53       0.58
#
#       alcohol  quality
# 696       9.5        6
# ...

# %%
df_AnanyaJalonha.shape
# Out:
# (1599, 12)

# %%
df_AnanyaJalonha.info
# Out:
# <bound method DataFrame.info of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 696             7.0              0.65         0.02             2.1      0.066
# 1398            7.0              0.60         0.12             2.2      0.083
# 1100            8.4              0.34         0.42             2.1      0.072
# 196             7.3              0.58         0.30             2.4      0.074
# 894             7.2              0.63         0.03             2.2      0.080
# ...             ...               ...          ...             ...        ...
# 1496            7.7              0.54         0.26             1.9      0.089
# 299             6.9              0.67         0.06             2.1      0.080
# 665             9.4              0.59         0.14             2.0      0.084
# 1403            7.2              0.33         0.33             1.7      0.061
# 1276            8.5              0.40         0.40             6.3      0.050
#
# ...

# %%
df_AnanyaJalonha.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df_AnanyaJalonha.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df_AnanyaJalonha.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# DATA VISUALIZATION

# %%
sns.distplot(df_AnanyaJalonha.pH)
# Out:
# <ipython-input-67-0af99ecd68bd>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_AnanyaJalonha.pH)
# <Axes: xlabel='pH', ylabel='Density'>

# %%
sns.displot(df_AnanyaJalonha.pH)

# %%
sns.lineplot(x=df_AnanyaJalonha['pH'],y=df_AnanyaJalonha['density'])
# Out:
# <Axes: xlabel='pH', ylabel='density'>

# %%
sns.scatterplot(x=df_AnanyaJalonha['pH'],y=df_AnanyaJalonha['density'])
# Out:
# <Axes: xlabel='pH', ylabel='density'>

# %%
sns.pairplot(df_AnanyaJalonha)

# %%
import seaborn as sns
sns.heatmap(df_AnanyaJalonha.corr(),annot =True)
# Out:
# <Axes: >

# %%
sns.boxplot(df_AnanyaJalonha.quality)
# Out:
# <Axes: >

# %% [markdown]
# MACHINE LEARNING MODELLING

# %% [markdown]
# TEST TRAIN SPLIT

# %%
df_AnanyaJalonha.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 32              8.3             0.655         0.12             2.3      0.083
# 1337            6.0             0.500         0.00             1.4      0.057
# 1041            6.9             0.490         0.19             1.7      0.079
# 1148            7.8             0.390         0.42             2.0      0.086
# 683             8.1             0.780         0.23             2.6      0.059
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 32                   15.0                 113.0  0.99660  3.17       0.66
# 1337                 15.0                  26.0  0.99448  3.36       0.45
# 1041                 13.0                  26.0  0.99547  3.38       0.64
# 1148                  9.0                  21.0  0.99526  3.39       0.66
# 683                   5.0                  15.0  0.99700  3.37       0.56
#
#       alcohol  quality
# 32        9.8        5
# ...

# %%
y=df_AnanyaJalonha.quality

# %%
y
# Out:
# 32      5
# 1337    5
# 1041    6
# 1148    6
# 683     5
#        ..
# 1523    5
# 783     5
# 1128    5
# 1522    5
# 193     5
# Name: quality, Length: 1599, dtype: int64

# %%
x=df_AnanyaJalonha.drop(columns=['quality'],axis=1)
x.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 32              8.3             0.655         0.12             2.3      0.083
# 1337            6.0             0.500         0.00             1.4      0.057
# 1041            6.9             0.490         0.19             1.7      0.079
# 1148            7.8             0.390         0.42             2.0      0.086
# 683             8.1             0.780         0.23             2.6      0.059
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 32                   15.0                 113.0  0.99660  3.17       0.66
# 1337                 15.0                  26.0  0.99448  3.36       0.45
# 1041                 13.0                  26.0  0.99547  3.38       0.64
# 1148                  9.0                  21.0  0.99526  3.39       0.66
# 683                   5.0                  15.0  0.99700  3.37       0.56
#
#       alcohol
# 32        9.8
# 1337      9.5
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scale =MinMaxScaler()
x=pd.DataFrame(scale.fit_transform(x),columns =x.columns)

# %%
x.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.327434          0.366438         0.12        0.095890   0.118531
# 1       0.123894          0.260274         0.00        0.034247   0.075125
# 2       0.203540          0.253425         0.19        0.054795   0.111853
# 3       0.283186          0.184932         0.42        0.075342   0.123539
# 4       0.309735          0.452055         0.23        0.116438   0.078464
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.197183              0.378092  0.479442  0.338583   0.197605
# 1             0.197183              0.070671  0.323789  0.488189   0.071856
# 2             0.169014              0.070671  0.396476  0.503937   0.185629
# 3             0.112676              0.053004  0.381057  0.511811   0.197605
# 4             0.056338              0.031802  0.508811  0.496063   0.137725
#
#     alcohol
# 0  0.215385
# 1  0.169231
# 2  0.215385
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.2,random_state =0)

# %%
x_train.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 642        0.256637          0.253425         0.20        0.116438   0.534224
# 679        0.159292          0.308219         0.12        0.095890   0.180301
# 473        0.274336          0.390411         0.05        0.123288   0.105175
# 390        0.557522          0.061644         0.49        0.130137   0.126878
# 1096       0.150442          0.308219         0.28        0.082192   0.060100
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 642              0.098592              0.028269  0.494126  0.370079
# 679              0.338028              0.106007  0.375918  0.574803
# 473              0.197183              0.074205  0.538179  0.409449
# 390              0.140845              0.091873  0.523495  0.377953
# 1096             0.169014              0.151943  0.269457  0.527559
#
#       sulphates   alcohol
# 642    0.341317  0.323077
# 679    0.227545  0.446154
# ...

# %%
x_test.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1109       0.212389          0.363014         0.02        0.082192   0.090150
# 1032       0.477876          0.315068         0.22        0.068493   0.113523
# 1002       0.274336          0.328767         0.06        0.075342   0.111853
# 487        0.318584          0.308219         0.26        0.089041   0.080134
# 979        0.486726          0.130137         0.44        0.095890   0.113523
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 1109             0.098592              0.067138  0.523495  0.574803
# 1032             0.112676              0.091873  0.538179  0.307087
# 1002             0.253521              0.123675  0.506608  0.511811
# 487              0.380282              0.208481  0.428047  0.440945
# 979              0.295775              0.141343  0.640969  0.456693
#
#       sulphates   alcohol
# 1109   0.203593  0.169231
# 1032   0.131737  0.169231
# ...

# %% [markdown]
# EVALUATING MODEL AND ACCURACY

# %% [markdown]
# FROM
# Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lr.predict(x_test)

# %%
y_predict1=lr.predict(x_train)

# %%
y_predict
# Out:
# array([5.24219891, 5.39731902, 5.46571329, 5.34780417, 5.6836305 ,
#        5.79844232, 5.33531936, 5.23891289, 5.69843984, 6.14478014,
#        5.48439542, 6.03156825, 6.58131274, 6.07147388, 5.26042216,
#        4.78577514, 5.40600579, 6.21509092, 5.76528723, 5.54910644,
#        5.80484053, 4.95534559, 5.05474369, 5.17775195, 5.33206476,
#        6.66927492, 6.02669423, 6.26982988, 5.18200375, 6.09140599,
#        4.9782811 , 5.92130368, 5.29258862, 5.5864778 , 5.85608694,
#        6.21472422, 4.97205253, 6.15985009, 5.41672438, 6.47928085,
#        5.4280028 , 5.27630665, 5.00768473, 6.79726864, 6.42706555,
#        5.20043085, 5.3501709 , 4.89406364, 5.8352292 , 6.06678371,
#        5.20618679, 4.9647261 , 5.37517894, 5.36921607, 4.95322935,
#        5.80663529, 5.33718893, 5.90970145, 6.08312843, 5.47700725,
#        5.6107452 , 5.03510541, 4.80493493, 5.98863094, 5.50729465,
#        5.48820441, 6.12936468, 6.17203456, 5.21596806, 5.74690657,
# ...

# %%
quality =pd.DataFrame({'Actual_quality':y_test,'Predicted_quality':y_predict})
quality
# Out:
#       Actual_quality  Predicted_quality
# 696                6           5.242199
# 622                5           5.397319
# 995                6           5.465713
# 213                5           5.347804
# 113                6           5.683630
# ...              ...                ...
# 453                7           6.069459
# 1265               6           5.563635
# 1233               4           5.693698
# 674                6           5.661532
# 1027               5           5.574552
#
# [320 rows x 2 columns]

# %%
from sklearn import metrics
print(metrics.r2_score(y_test,y_predict))
# Out:
# 0.3188637504724987

# %%
from sklearn import metrics
print(metrics.r2_score(y_train,y_predict1))
# Out:
# 0.36553085964794774

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr_pred=lr.predict(x_test)

# %%
from sklearn import metrics
print(metrics.r2_score(y_test,lr_pred))
accuracy_score(y_test,lr_pred)
# Out:
# 0.15776686743938861
# 0.596875

# %% [markdown]
# FROM Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

# %%
param_grid = {
    'max_depth': [3, 4, 5, 6],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy']
}

# %%
model_dc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
grid_search = GridSearchCV(DecisionTreeClassifier(), param_grid, cv=5, n_jobs=-1)
grid_search.fit(x_train, y_train)

best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 5}

# %%
best_model_dc = DecisionTreeClassifier(**best_params)
best_model_dc.fit(x_train, y_train)


y_pred = best_model_dc.predict(x_test)

# %%
test_accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy:", test_accuracy)

train_pred = best_model_dc.predict(x_train)
train_accuracy = accuracy_score(y_train, train_pred)
print("Training Accuracy:", train_accuracy)


print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Test Accuracy: 0.634375
# Training Accuracy: 0.6559812353401094
# Classification Report:
#                precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00        10
#            5       0.68      0.80      0.73       132
#            6       0.59      0.66      0.62       135
#            7       0.60      0.22      0.32        41
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.63       320
#    macro avg       0.37      0.33      0.34       320
# weighted avg       0.61      0.63      0.61       320
#
# Confusion Matrix:
#  [[  0   6   4   0   0]
#  [  0 105  26   1   0]
#  [  0  42  89   4   0]
#  [  0   2  30   9   0]
#  [  0   0   1   1   0]]
# ...

# %% [markdown]
# From Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model =RandomForestClassifier(criterion='entropy')

# %%
rf_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy')

# %%
rf_pred=rf_model.predict(x_test)
rf_pred1=rf_model.predict(x_train)

# %%
accuracy_score(y_test,rf_pred)
# Out:
# 0.721875

# %%
accuracy_score(y_train,rf_pred1)
# Out:
# 1.0

# %%
print(classification_report(y_test,rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00        10
#            5       0.73      0.85      0.79       132
#            6       0.69      0.72      0.71       135
#            7       0.84      0.51      0.64        41
#            8       1.00      0.50      0.67         2
#
#     accuracy                           0.72       320
#    macro avg       0.65      0.52      0.56       320
# weighted avg       0.71      0.72      0.71       320
